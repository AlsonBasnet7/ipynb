# %%
import numpy as np

# %%
arr1 = np.array([1,2,3,4,5]) # this is the example of 1D array

# %%
arr2=np.array([[1,2,3], [5,,6,4]])# this is the example of 2D array
# Out:
#   Cell In[12], line 1
#     arr2=np.array([[1,2,3],[5,,6,4]])# this is the example of 2D array
#                               ^
# SyntaxError: invalid syntax

# %%
print(arr1)
print(arr2)
# Out:
# [1 2 3 4 5]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 print(arr1)
# ----> 2 print(arr2)
#
# NameError: name 'arr2' is not defined
