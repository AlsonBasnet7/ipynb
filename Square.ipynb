# %%
import numpy as np
import time

# %%
size=100000
list1=list(range(size))

# %%
start= time.time()
list_squares=[x ** 2 for x in list1]
end=time.time()
print("The time of the output is:",end-start)
# Out:
# The time of the output is: 0.011346817016601562

# %%
arr1=np.array(list1)

# %%
start=time.time()
numpy_squared=arr1**2
end=time.time()
print("The time taken to calculate the sqaure is:",end-start)
# Out:
# The time taken to calculate the sqaure is: 0.0007429122924804688
