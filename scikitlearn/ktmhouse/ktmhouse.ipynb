# %%
import pandas as pd

# %%
df= pd.read_excel("house.xlsx")

# %%
df.head()
# Out:
#                      TITLE                LOCATION         PRICE LAND AREA  \
# 0           House for Sale        Imadol, Lalitpur   Rs. 2.9 Cr   4.0 aana
# 1           House for Sale     Satdobato, Lalitpur  Rs. 4.75 Cr   3.0 aana
# 2     4 BHK House for Sale        Imadol, Lalitpur  Rs. 1.99 Cr   2.3 aana
# 3  Bungalow House for Sale    Bhaisepati, Lalitpur     Rs. 4 Cr   7.0 aana
# 4           House for Rent  Maharajgunj, Kathmandu  Rs. 12000000  6.0 aana
#
#   BUILDUP AREA ROAD ACCESS      FACING  FLOOR  BEDROOM  BATHROOM BUILT YEAR  \
# 0          NaN     12 Feet        West    3.0      5.0       4.0   2076 B.S
# 1          NaN     10 Feet        West    4.5      5.0       6.0   2076 B.S
# 2          NaN     10 Feet        West    2.5      4.0       4.0   2060 B.S
# 3          NaN     12 Feet  North-West    2.5      4.0       3.0   2059 B.S
# 4          NaN     20 Feet       South    2.0      4.0       4.0   2071 B.S
#
# ...

# %%
df.tail()
# Out:
#                             TITLE                     LOCATION  \
# 3413       Padma Colony Phase III        Sitapiala,  Kathmandu
# 3414        Bhatbhateni Apartment      Bhatbhateni,  Kathmandu
# 3415  स्यूचाटार        Syuchatar,  Kathmandu
# 3416        Sano Bharayang Colony   Sano Bharayang,  Kathmandu
# 3417       Buddhanilkatha Banglow   Budhanilkantha,  Kathmandu
#
#                PRICE  LAND AREA BUILDUP AREA ROAD ACCESS      FACING  FLOOR  \
# 3413  Rs. 26,000,000   4.5 aana          NaN     16 Feet       North    2.5
# 3414  Rs. 30,000,000   4.5 aana   1700 Sq.ft     16 Feet       South    3.0
# 3415    Rs. 16000000  4.7 aana    1700 Sq.ft     16 Feet       South    2.5
# 3416      Rs. 3.5 Cr   6.3 aana   3505 Sq.ft     16 Feet  North-West    2.5
# 3417    Rs. 48000000     8 aana       5 aana     16 Feet       North    2.0
#
#       BEDROOM  BATHROOM BUILT YEAR            PARKING  \
# 3413      4.0       4.0   2076 B.S    1 Car & 3 Bikes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3418 entries, 0 to 3417
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   TITLE         3418 non-null   object
#  1   LOCATION      3418 non-null   object
#  2   PRICE         3418 non-null   object
#  3   LAND AREA     3329 non-null   object
#  4   BUILDUP AREA  719 non-null    object
#  5   ROAD ACCESS   3409 non-null   object
#  6   FACING        3212 non-null   object
#  7   FLOOR         3323 non-null   float64
#  8   BEDROOM       3136 non-null   float64
#  9   BATHROOM      3072 non-null   float64
#  10  BUILT YEAR    3357 non-null   object
#  11  PARKING       632 non-null    object
#  12  AMENITIES     3418 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 347.3+ KB

# %%
df['FACING'].value_counts()
# Out:
# FACING
# East            709
# South           672
# North           478
# West            476
# South-East      250
# North-East      180
# South-West      150
# North-West       97
# EAST             29
# SOUTH            25
# NORTH            22
# South East       17
# WEST             17
# South West       14
# EAST-NORTH       13
# North East       13
# SOUTH-WEST        8
# EAST-SOUTH        6
# East-South        5
# NORTH-WEST        4
# SOUTH-EAST        3
# NORTH/EAST        3
# South-EAST        3
# North West        3
# west              2
# WEST / NORTH      2
# south             2
# South-east        1
# East-North        1
# WEST-NORTH        1
# south west        1
# EAST/WEST         1
# East/South        1
# North- East       1
# West-South        1
# WEST-SOUTH        1
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#              FLOOR      BEDROOM     BATHROOM
# count  3323.000000  3136.000000  3072.000000
# mean      2.668492     5.399235     4.187826
# std       0.726047     3.148436     2.674617
# min       1.000000     1.000000     1.000000
# 25%       2.500000     4.000000     3.000000
# 50%       2.500000     5.000000     4.000000
# 75%       2.500000     6.000000     5.000000
# max       8.000000   100.000000   100.000000

# %% [markdown]
# Now we are creating the Histogram

# %%
import matplotlib.pyplot as plt

# %%
df.hist(bins=50,figsize=(12,8))
# Out:
# array([[<Axes: title={'center': 'FLOOR'}>,
#         <Axes: title={'center': 'BEDROOM'}>],
#        [<Axes: title={'center': 'BATHROOM'}>, <Axes: >]], dtype=object)

# %%
#creating a test set; it is necessary to create test set to remove the Data Snooping Bias

# %%
import numpy as np

# %%
def shuffle_and_split(data,test_ratio):
    shuffle_indices = np.random.permutation(len(data)) #this returns the shuffled indices.
    test_set_size= int(len(data)*test_ratio)
    test_indices= shuffle_indices[:test_set_size]
    train_indices = shuffle_indices[test_set_size:]
    return data.iloc[train_indices],data.iloc[test_indices]

# %%
shuffle_and_split(df,0.4)
# Out:
# (                                                TITLE                LOCATION  \
#  2460      House on sale near Chundevi Temple, Katunje      Katunje, Bhaktapur
#  2030         Residential house on sale in Mandikhatar  Mandikhatar, Kathmandu
#  3312                          SItapaila House on Sale   Sitapaila,  Kathmandu
#  881                    5 BHK house for sale in Imadol        Imadol, Lalitpur
#  2238   House for sale near Karuna Hospital, Chunikhel    Chunikhel, Kathmandu
#  ...                                               ...                     ...
#  1044             Brand new house on sale in Dahachowk    Dahachowk, Kathmandu
#  2447        House on sale at Sahayoginagar, Koteshwor    Koteshwor, Kathmandu
#  1626  Residential house for sale at Baseni, Bharatpur         Baseni, Chitwan
#  1220       Newly built bungalow on sale in Bhaisepati    Bhaisepati, Lalitpur
#  1337           Semi furnished house on sale in Imadol        Imadol, Lalitpur
#
# ...
