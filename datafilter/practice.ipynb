# %%
#we are going to filter some data out

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("data.csv")

# %%
df.head()
# Out:
#    EmployeeID           Name   Age Department  Salary JoiningDate  \
# 0         101  Alice Johnson  28.0         IT   65000  2022-01-15
# 1         102      Bob Smith  35.0         HR   55000  2021-03-10
# 2         103  Charlie Brown  42.0    Finance   72000  2019-07-20
# 3         104   David Wilson  29.0         IT   68000  2023-05-11
# 4         105     Emma Davis  31.0  Marketing   50000  2020-09-18
#
#           Phone              Email       City
# 0  9.841000e+09    alice@gmail.com  Kathmandu
# 1  9.841000e+09      bob@gmail.com    Pokhara
# 2  9.841000e+09  charlie@gmail.com   Lalitpur
# 3           NaN    david@gmail.com  Bhaktapur
# 4  9.841000e+09     emma@gmail.com  Kathmandu

# %%
df[df["Age"]>20] #here we will print the dataset whose ages are greateer than 20
# Out:
#     EmployeeID           Name   Age Department  Salary JoiningDate  \
# 0          101  Alice Johnson  28.0         IT   65000  2022-01-15
# 1          102      Bob Smith  35.0         HR   55000  2021-03-10
# 2          103  Charlie Brown  42.0    Finance   72000  2019-07-20
# 3          104   David Wilson  29.0         IT   68000  2023-05-11
# 4          105     Emma Davis  31.0  Marketing   50000  2020-09-18
# 6          107      Grace Lee  26.0         HR   48000  2024-02-14
# 7          108   Henry Walker  39.0         IT   82000  2017-04-30
# 8          109  Isabella Hall  33.0  Marketing   59000  2022-08-05
# 9          110     Jack White  45.0    Finance   91000  2016-06-12
# 10         111    Karen Young  27.0      Sales   47000  2023-01-09
# 11         112     Liam Scott  36.0      Sales   61000  2021-12-19
# 12         113      Mia Green  24.0         HR   46000  2024-04-25
# 13         114      Noah King  38.0  Marketing   64000  2020-07-17
# ...

# %%
#if we want to perfom the multiple conditions

# %%
df(df["Age">20)& (df["Deparment"]=="IT"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df[df["Age">20]& [f["Deparment"]=="IT"]]
#
# TypeError: '>' not supported between instances of 'str' and 'int'
