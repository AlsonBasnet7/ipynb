# %%
import json

# %%
data={"name":"Alice","age":25,"city":"New York"}

# %%
json_string=json.dumps(data)

# %%
print(json_string) #Here we will have the output.
# Out:
# {"name": "Alice", "age": 25, "city": "New York"}

# %%
print(type(json_string)) #it will show the type
# Out:
# <class 'str'>
